# %%
import os
import numpy as np
import tensorflow as tf
import time
import datetime
import matplotlib.pyplot as plt
np.random.seed(3122)
tf.random.set_seed(3131)
category_num = 10
#MNIST = tf.keras.datasets.fashion_mnist
MNIST = tf.keras.datasets.mnist

# %%
#load data and rescale
(x_train, y_train),(x_test, y_test) = MNIST.load_data()
x_train = np.reshape(x_train / 255.0, (len(x_train),-1))
x_test = np.reshape(x_test / 255.0, (len(x_test),-1))

# %%
#Use one-hot encoding to represent category
one_hot = lambda m: [1 if i == m else 0 for i in range(category_num)]
y_train = np.array([one_hot(y) for y in y_train])
y_test = np.array([one_hot(y) for y in y_test])

# %%
class MLP(tf.keras.Model):
    def __init__(self, size_input, size_hidden, size_output, device=None):
        super(MLP, self).__init__()
        """
        size_input: int, size of input layer
        size_hidden: int, size of hidden layer
        size_output: int, size of output layer
        device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
        """
        self.size_input, self.size_hidden, self.size_output, self.device =\
        size_input, size_hidden, size_output, device

        # Initialize weights between input layer and hidden layer 1
        self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden]))
        # Initialize biases for hidden layer 1
        self.b1 = tf.Variable(tf.random.normal([1, self.size_hidden]))
         # Initialize weights between hidden layer 1 and hidden layer 2
        self.W2 = tf.Variable(tf.random.normal([self.size_hidden, self.size_hidden]))
        # Initialize biases for hidden layer 2
        self.b2 = tf.Variable(tf.random.normal([1, self.size_hidden]))
         # Initialize weights between hidden layer 2 and output layer
        self.W3 = tf.Variable(tf.random.normal([self.size_hidden, self.size_output]))
        # Initialize biases for output layer
        self.b3 = tf.Variable(tf.random.normal([1, self.size_output]))

        # Define variables to be updated during backpropagation
        self.MLP_variables = [self.W1, self.W2, self.W3, self.b1, self.b2, self.b3]
        # self.MLP_variables = [self.W1, self.W3, self.b1, self.b3]

    
    def forward(self, X, dropout_rate=0):
        """
        forward pass
        X: Tensor, inputs
        """
        if self.device is not None:
            with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
                self.y = self.compute_output(X, dropout_rate=dropout_rate)
        else:
            self.y = self.compute_output(X, dropout_rate=dropout_rate)

        return self.y
  
    def loss(self, y_pred, y_true, L1=0, L2=0):
        '''
        y_pred - Tensor of shape (batch_size, size_output)
        y_true - Tensor of shape (batch_size, size_output)
        '''
        y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
        y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
        l2_penlty = tf.nn.l2_loss(self.W1)*L2
        loss_with_l2 = l2_penlty+tf.losses.categorical_crossentropy(y_true_tf, y_pred_tf)
        return tf.losses.categorical_crossentropy(y_true_tf, y_pred_tf)
  
    def backward(self, X_train, y_train, dropout_rate, learning_rate, L1=0, L2=0):
        """
        backward pass
        """
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        with tf.GradientTape() as tape:
            predicted = self.forward(X_train,dropout_rate=dropout_rate)
            current_loss = self.loss(predicted, y_train)
        grads = tape.gradient(current_loss, self.MLP_variables)
        optimizer.apply_gradients(zip(grads, self.MLP_variables))
        return current_loss, predicted
        
        
    def compute_output(self, X, dropout_rate=0):
        """
        Custom method to obtain output tensor during forward pass
        """
        # Cast X to float32
        X_tf = tf.cast(X, dtype=tf.float32)
        #Remember to normalize your dataset before moving forward
        # Compute values in hidden layer 1
        what = tf.matmul(X_tf, self.W1) + self.b1
        hhat = tf.nn.relu(what)
        hhat = tf.nn.dropout(hhat, rate = dropout_rate)

        # Compute values in hidden layer 2
        what = tf.matmul(hhat, self.W2) + self.b2
        hhat = tf.nn.relu(what)
        hhat = tf.nn.dropout(hhat, rate = dropout_rate)

        # Compute output
        output = tf.matmul(hhat, self.W3) + self.b3
        #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this
        #Second add tf.Softmax(output) and then return this variable
        return tf.nn.softmax(output)
#         return output
# Set hyper-parameters

# %%
#Hyer-paarameter
Dropout_rate = 0
Batch_Size = 300
Hidden_Size = 128
Epochs_num = 50
Learning_rate = 0.003
L2_Penalty = 0.3

# %%
size_input = len(x_train[0])
size_hidden = Hidden_Size
size_output = len(y_train[0])
number_of_train_examples = len(x_train[0])
number_of_test_examples = len(x_test[0])

# %%
rand_seed = np.random.randint(low=1,high=1000,size=10)
loss_res = np.zeros(10)
train_acc = np.zeros(10)
test_acc = np.zeros(10)
for k in range(20):
    #np.random.seed(rand_seed[k])
    #tf.random.set_seed(rand_seed[k])
    L2_Penalty = 0.05*k
    #Dropout_rate = 0.05*k
    mlp_on_gpu = MLP(size_input, size_hidden, size_output, device='cpu')
    time_start = time.time()
    epoch = 0
    last_loss = 0
    for epoch in range(Epochs_num):
        time_start = time.time()
        loss_total_gpu = tf.zeros([1,1], dtype=tf.float32)
        train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(25, seed=epoch*(1234)).batch(Batch_Size)
        for inputs, outputs in train_ds:
            cur_loss, preds = mlp_on_gpu.backward(inputs, outputs, dropout_rate=Dropout_rate, learning_rate=Learning_rate, L2=L2_Penalty)
            loss_total_gpu += cur_loss
      # Calculate Accuracy
        train_accuracy, test_accuracy = tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.CategoricalAccuracy()
        train_accuracy.update_state(y_train, mlp_on_gpu.forward(x_train))
        test_accuracy.update_state(y_test, mlp_on_gpu.forward(x_test))

        print(f'Epoch = {epoch+1} , Training Cross Entropy:= {np.sum(loss_total_gpu) / len(x_train)} , Training Accuracy:= {train_accuracy.result().numpy()} , Test Accuracy:= {test_accuracy.result().numpy()}')
        time_taken = time.time() - time_start
        print('Time : {:.2f}s'.format(time_taken))
    loss_res[k] = np.sum(loss_total_gpu) / len(x_train)
    train_acc[k] = train_accuracy.result().numpy()
    test_acc[k] = test_accuracy.result().numpy()
# Out:
# Epoch = 1 , Training Cross Entropy:= 9.966797916666666 , Training Accuracy:= 0.45445001125335693 , Test Accuracy:= 0.4602000117301941
# Time : 2.67s
# Epoch = 2 , Training Cross Entropy:= 7.8688515625 , Training Accuracy:= 0.5565500259399414 , Test Accuracy:= 0.5598999857902527
# Time : 2.63s
# Epoch = 3 , Training Cross Entropy:= 6.717480208333333 , Training Accuracy:= 0.5999500155448914 , Test Accuracy:= 0.6007000207901001
# Epoch = 7 , Training Cross Entropy:= 3.2357098958333332 , Training Accuracy:= 0.7910333275794983 , Test Accuracy:= 0.7896999716758728
# Time : 2.68s
# Epoch = 8 , Training Cross Entropy:= 3.1591984375 , Training Accuracy:= 0.8050166964530945 , Test Accuracy:= 0.8047999739646912
# Time : 2.65s
# Epoch = 9 , Training Cross Entropy:= 3.0857880208333333 , Training Accuracy:= 0.8109666705131531 , Test Accuracy:= 0.8098999857902527
# Time : 2.69s
# Epoch = 10 , Training Cross Entropy:= 3.02438046875 , Training Accuracy:= 0.8122000098228455 , Test Accuracy:= 0.810699999332428
# Time : 2.67s
# Epoch = 11 , Training Cross Entropy:= 2.92423359375 , Training Accuracy:= 0.8111166954040527 , Test Accuracy:= 0.809499979019165
# Time : 2.68s
# Epoch = 12 , Training Cross Entropy:= 2.9251911458333333 , Training Accuracy:= 0.8214666843414307 , Test Accuracy:= 0.8181999921798706
# Time : 2.69s
# Epoch = 13 , Training Cross Entropy:= 2.854315885416667 , Training Accuracy:= 0.8228333592414856 , Test Accuracy:= 0.8224999904632568
# Time : 2.68s
# Epoch = 14 , Training Cross Entropy:= 2.805388541666667 , Training Accuracy:= 0.8233333230018616 , Test Accuracy:= 0.8227999806404114
# Time : 2.65s
# Epoch = 15 , Training Cross Entropy:= 2.7989684895833333 , Training Accuracy:= 0.828416645526886 , Test Accuracy:= 0.8248999714851379
# Time : 2.68s
# Epoch = 16 , Training Cross Entropy:= 2.7865171875 , Training Accuracy:= 0.8333500027656555 , Test Accuracy:= 0.8282999992370605
# Time : 2.69s
# Epoch = 17 , Training Cross Entropy:= 2.7180052083333335 , Training Accuracy:= 0.8248500227928162 , Test Accuracy:= 0.8223999738693237
# Time : 2.67s
# Epoch = 18 , Training Cross Entropy:= 2.7209934895833334 , Training Accuracy:= 0.8318833112716675 , Test Accuracy:= 0.8284000158309937
# Time : 2.68s
# Epoch = 19 , Training Cross Entropy:= 2.689600260416667 , Training Accuracy:= 0.8309833407402039 , Test Accuracy:= 0.82669997215271
# Time : 2.74s
# Epoch = 20 , Training Cross Entropy:= 2.6656739583333335 , Training Accuracy:= 0.8345333337783813 , Test Accuracy:= 0.8305000066757202
# Time : 2.69s
# Epoch = 21 , Training Cross Entropy:= 2.650620052083333 , Training Accuracy:= 0.835266649723053 , Test Accuracy:= 0.8299999833106995
# Time : 2.67s
# Epoch = 22 , Training Cross Entropy:= 2.6259020833333335 , Training Accuracy:= 0.8375666737556458 , Test Accuracy:= 0.8327000141143799
# Time : 2.68s
# Epoch = 23 , Training Cross Entropy:= 2.609696614583333 , Training Accuracy:= 0.8366833329200745 , Test Accuracy:= 0.832099974155426
# Time : 2.71s
# Epoch = 24 , Training Cross Entropy:= 2.6117658854166668 , Training Accuracy:= 0.8418999910354614 , Test Accuracy:= 0.8370000123977661
# Time : 2.69s
# Epoch = 25 , Training Cross Entropy:= 2.5900638020833333 , Training Accuracy:= 0.8314333558082581 , Test Accuracy:= 0.8305000066757202
# Time : 2.67s
# Time : 2.69s
# Epoch = 46 , Training Cross Entropy:= 2.3887315104166666 , Training Accuracy:= 0.8521833419799805 , Test Accuracy:= 0.8452000021934509
# Time : 2.68s
# Epoch = 47 , Training Cross Entropy:= 2.357553125 , Training Accuracy:= 0.8523666858673096 , Test Accuracy:= 0.8461999893188477
# Time : 2.68s
# Epoch = 48 , Training Cross Entropy:= 2.3782984375 , Training Accuracy:= 0.8530166745185852 , Test Accuracy:= 0.8457000255584717
# Time : 2.71s
# Epoch = 49 , Training Cross Entropy:= 2.368295572916667 , Training Accuracy:= 0.8548333048820496 , Test Accuracy:= 0.8463000059127808
# Time : 2.63s
# Epoch = 50 , Training Cross Entropy:= 2.3543239583333335 , Training Accuracy:= 0.8529499769210815 , Test Accuracy:= 0.8447999954223633
# Time : 2.68s
# Epoch = 1 , Training Cross Entropy:= 10.649365625 , Training Accuracy:= 0.45910000801086426 , Test Accuracy:= 0.4659999907016754
# Time : 2.68s
# Epoch = 2 , Training Cross Entropy:= 8.094501041666666 , Training Accuracy:= 0.5159333348274231 , Test Accuracy:= 0.5203999876976013
# Time : 2.68s
# Epoch = 3 , Training Cross Entropy:= 7.649946875 , Training Accuracy:= 0.5333666801452637 , Test Accuracy:= 0.5412999987602234
# Time : 2.69s
# Epoch = 4 , Training Cross Entropy:= 7.476725 , Training Accuracy:= 0.5414000153541565 , Test Accuracy:= 0.5468000173568726
# Time : 2.69s
# Epoch = 5 , Training Cross Entropy:= 7.370196875 , Training Accuracy:= 0.5409666895866394 , Test Accuracy:= 0.5428000092506409
# Time : 2.67s
# Epoch = 6 , Training Cross Entropy:= 7.275634895833333 , Training Accuracy:= 0.548383355140686 , Test Accuracy:= 0.551800012588501
# Time : 2.66s
# Epoch = 7 , Training Cross Entropy:= 7.235757291666666 , Training Accuracy:= 0.5543833374977112 , Test Accuracy:= 0.5570999979972839
# Time : 2.68s
# Epoch = 8 , Training Cross Entropy:= 7.169626041666667 , Training Accuracy:= 0.5571666955947876 , Test Accuracy:= 0.5612000226974487
# Time : 2.67s
# Epoch = 9 , Training Cross Entropy:= 7.153059375 , Training Accuracy:= 0.5567166805267334 , Test Accuracy:= 0.5633999705314636
# Time : 2.67s
# Epoch = 10 , Training Cross Entropy:= 7.117092708333334 , Training Accuracy:= 0.5583666563034058 , Test Accuracy:= 0.5629000067710876
# Time : 2.65s
# Epoch = 11 , Training Cross Entropy:= 7.0827760416666665 , Training Accuracy:= 0.5629166960716248 , Test Accuracy:= 0.5672000050544739
# Time : 2.69s
# Epoch = 12 , Training Cross Entropy:= 7.0571453125 , Training Accuracy:= 0.5604000091552734 , Test Accuracy:= 0.5636000037193298
# Time : 2.67s
# Epoch = 13 , Training Cross Entropy:= 7.037182291666666 , Training Accuracy:= 0.5638166666030884 , Test Accuracy:= 0.5672000050544739
# Time : 2.68s
# Epoch = 14 , Training Cross Entropy:= 7.044589583333333 , Training Accuracy:= 0.5596666932106018 , Test Accuracy:= 0.5619000196456909
# Time : 2.68s
# Epoch = 15 , Training Cross Entropy:= 7.0050364583333335 , Training Accuracy:= 0.5657333135604858 , Test Accuracy:= 0.5685999989509583
# Time : 2.69s
# Epoch = 16 , Training Cross Entropy:= 6.9997921875 , Training Accuracy:= 0.5679500102996826 , Test Accuracy:= 0.5698000192642212
# Time : 2.68s
# Epoch = 17 , Training Cross Entropy:= 6.9993125 , Training Accuracy:= 0.5647000074386597 , Test Accuracy:= 0.5694000124931335
# Time : 2.68s
# Epoch = 18 , Training Cross Entropy:= 6.97689375 , Training Accuracy:= 0.5663333535194397 , Test Accuracy:= 0.5680000185966492
# Time : 2.68s
# Epoch = 19 , Training Cross Entropy:= 6.98685 , Training Accuracy:= 0.5677499771118164 , Test Accuracy:= 0.5681999921798706
# Time : 2.67s
# Epoch = 20 , Training Cross Entropy:= 6.937308333333333 , Training Accuracy:= 0.5663333535194397 , Test Accuracy:= 0.5716999769210815
# Time : 2.68s
# Epoch = 21 , Training Cross Entropy:= 6.947767708333333 , Training Accuracy:= 0.5670999884605408 , Test Accuracy:= 0.5672000050544739
# Time : 2.66s
# Epoch = 22 , Training Cross Entropy:= 6.9298875 , Training Accuracy:= 0.569516658782959 , Test Accuracy:= 0.5719000101089478
# Time : 2.68s
# Epoch = 23 , Training Cross Entropy:= 6.9204375 , Training Accuracy:= 0.5698500275611877 , Test Accuracy:= 0.573199987411499
# Time : 2.76s
# Epoch = 24 , Training Cross Entropy:= 6.9052505208333335 , Training Accuracy:= 0.5666833519935608 , Test Accuracy:= 0.5665000081062317
# Time : 2.65s
# Epoch = 25 , Training Cross Entropy:= 6.912432291666667 , Training Accuracy:= 0.5698000192642212 , Test Accuracy:= 0.573199987411499
# Time : 2.67s
# Epoch = 26 , Training Cross Entropy:= 6.891034895833333 , Training Accuracy:= 0.5744333267211914 , Test Accuracy:= 0.5771999955177307
# Time : 2.64s
# Epoch = 27 , Training Cross Entropy:= 6.8842260416666665 , Training Accuracy:= 0.5735833048820496 , Test Accuracy:= 0.5752999782562256
# Time : 2.67s
# Epoch = 28 , Training Cross Entropy:= 6.870464583333334 , Training Accuracy:= 0.5743333101272583 , Test Accuracy:= 0.5767999887466431
# Time : 2.66s
# Epoch = 29 , Training Cross Entropy:= 6.891573958333334 , Training Accuracy:= 0.5739166736602783 , Test Accuracy:= 0.5738999843597412
# Time : 2.66s
# Epoch = 30 , Training Cross Entropy:= 6.8955078125 , Training Accuracy:= 0.5742499828338623 , Test Accuracy:= 0.5764999985694885
# Time : 2.67s
# Epoch = 31 , Training Cross Entropy:= 6.869058854166667 , Training Accuracy:= 0.5743833184242249 , Test Accuracy:= 0.5759000182151794
# Time : 2.65s
# Epoch = 32 , Training Cross Entropy:= 6.869332291666667 , Training Accuracy:= 0.5728166699409485 , Test Accuracy:= 0.5769000053405762
# Time : 2.66s
# Epoch = 33 , Training Cross Entropy:= 6.849088020833333 , Training Accuracy:= 0.576366662979126 , Test Accuracy:= 0.5774999856948853
# Time : 2.67s
# Epoch = 34 , Training Cross Entropy:= 6.847454166666667 , Training Accuracy:= 0.5755500197410583 , Test Accuracy:= 0.5770000219345093
# Time : 2.67s
# Epoch = 35 , Training Cross Entropy:= 6.833017708333333 , Training Accuracy:= 0.5741166472434998 , Test Accuracy:= 0.5753999948501587
# Time : 2.68s
# Epoch = 36 , Training Cross Entropy:= 6.835088020833333 , Training Accuracy:= 0.5723666548728943 , Test Accuracy:= 0.5723000168800354
# Time : 2.68s
# Epoch = 37 , Training Cross Entropy:= 6.8497109375 , Training Accuracy:= 0.5706166625022888 , Test Accuracy:= 0.5716999769210815
# Time : 2.67s
# Epoch = 38 , Training Cross Entropy:= 6.840172916666667 , Training Accuracy:= 0.576116681098938 , Test Accuracy:= 0.5763000249862671
# Time : 2.67s
# Epoch = 39 , Training Cross Entropy:= 6.8311270833333335 , Training Accuracy:= 0.5775833129882812 , Test Accuracy:= 0.5787000060081482
# Time : 2.67s
# Epoch = 40 , Training Cross Entropy:= 6.846902083333333 , Training Accuracy:= 0.5722333192825317 , Test Accuracy:= 0.5737000107765198
# Time : 2.66s
# Epoch = 41 , Training Cross Entropy:= 6.820108333333334 , Training Accuracy:= 0.578000009059906 , Test Accuracy:= 0.5778999924659729
# Time : 2.68s
# Epoch = 42 , Training Cross Entropy:= 6.807791666666667 , Training Accuracy:= 0.5789499878883362 , Test Accuracy:= 0.5799999833106995
# Time : 2.65s
# Epoch = 43 , Training Cross Entropy:= 6.799272395833333 , Training Accuracy:= 0.5773000121116638 , Test Accuracy:= 0.5770999789237976
# Time : 2.71s
# Epoch = 44 , Training Cross Entropy:= 6.815927083333333 , Training Accuracy:= 0.5782833099365234 , Test Accuracy:= 0.5795999765396118
# Time : 2.67s
# Epoch = 45 , Training Cross Entropy:= 6.807779166666666 , Training Accuracy:= 0.5757166743278503 , Test Accuracy:= 0.5774000287055969
# Time : 2.67s
# Epoch = 46 , Training Cross Entropy:= 6.812526041666667 , Training Accuracy:= 0.5771999955177307 , Test Accuracy:= 0.5777999758720398
# Time : 2.69s
# Epoch = 47 , Training Cross Entropy:= 6.800417708333334 , Training Accuracy:= 0.5749333500862122 , Test Accuracy:= 0.5751000046730042
# Time : 2.71s
# Epoch = 48 , Training Cross Entropy:= 6.79804375 , Training Accuracy:= 0.5771166682243347 , Test Accuracy:= 0.5770000219345093
# Time : 2.69s
# Epoch = 49 , Training Cross Entropy:= 6.8113625 , Training Accuracy:= 0.5795999765396118 , Test Accuracy:= 0.5785999894142151
# Time : 2.69s
# Epoch = 50 , Training Cross Entropy:= 6.793213020833333 , Training Accuracy:= 0.5798166394233704 , Test Accuracy:= 0.5806000232696533
# Time : 2.69s
# Epoch = 1 , Training Cross Entropy:= 12.335525 , Training Accuracy:= 0.33096668124198914 , Test Accuracy:= 0.32739999890327454
# Time : 2.68s
# Epoch = 2 , Training Cross Entropy:= 10.521586458333333 , Training Accuracy:= 0.3679666519165039 , Test Accuracy:= 0.36980000138282776
# Time : 2.69s
# Epoch = 3 , Training Cross Entropy:= 9.232251041666666 , Training Accuracy:= 0.4635166525840759 , Test Accuracy:= 0.46239998936653137
# Time : 2.69s
# Epoch = 4 , Training Cross Entropy:= 7.630304166666667 , Training Accuracy:= 0.5687833428382874 , Test Accuracy:= 0.5679000020027161
# Time : 2.69s
# Epoch = 5 , Training Cross Entropy:= 6.199778645833334 , Training Accuracy:= 0.647266685962677 , Test Accuracy:= 0.6478999853134155
# Time : 2.69s
# Epoch = 6 , Training Cross Entropy:= 5.44134375 , Training Accuracy:= 0.6696500182151794 , Test Accuracy:= 0.6721000075340271
# Time : 2.70s
# Epoch = 7 , Training Cross Entropy:= 5.118444791666667 , Training Accuracy:= 0.6777499914169312 , Test Accuracy:= 0.679099977016449
# Time : 2.70s
# Epoch = 8 , Training Cross Entropy:= 4.978366666666667 , Training Accuracy:= 0.6975666880607605 , Test Accuracy:= 0.6970999836921692
# Time : 2.69s
# Epoch = 9 , Training Cross Entropy:= 4.8286625 , Training Accuracy:= 0.6995333433151245 , Test Accuracy:= 0.698199987411499
# Time : 2.68s
# Epoch = 10 , Training Cross Entropy:= 4.7986885416666665 , Training Accuracy:= 0.7067333459854126 , Test Accuracy:= 0.70660001039505
# Time : 2.68s
# Epoch = 11 , Training Cross Entropy:= 4.6930322916666665 , Training Accuracy:= 0.7106000185012817 , Test Accuracy:= 0.7064999938011169
# Time : 2.65s
# Epoch = 12 , Training Cross Entropy:= 4.623903645833333 , Training Accuracy:= 0.7159500122070312 , Test Accuracy:= 0.7128000259399414
# Time : 2.69s
# Epoch = 13 , Training Cross Entropy:= 4.5911510416666665 , Training Accuracy:= 0.7190666794776917 , Test Accuracy:= 0.7146999835968018
# Time : 2.69s
# Epoch = 14 , Training Cross Entropy:= 4.513588541666667 , Training Accuracy:= 0.7185666561126709 , Test Accuracy:= 0.7160999774932861
# Time : 2.68s
# Epoch = 15 , Training Cross Entropy:= 4.499251041666667 , Training Accuracy:= 0.718916654586792 , Test Accuracy:= 0.7167999744415283
# Time : 2.65s
# Epoch = 16 , Training Cross Entropy:= 4.465586979166667 , Training Accuracy:= 0.7236166596412659 , Test Accuracy:= 0.7196000218391418
# Time : 2.72s
# Epoch = 17 , Training Cross Entropy:= 4.429420833333333 , Training Accuracy:= 0.7241166830062866 , Test Accuracy:= 0.7207000255584717
# Time : 2.72s
# Epoch = 18 , Training Cross Entropy:= 4.4342875 , Training Accuracy:= 0.7251333594322205 , Test Accuracy:= 0.7210000157356262
# Time : 2.72s
# Epoch = 19 , Training Cross Entropy:= 4.423214583333333 , Training Accuracy:= 0.7256166934967041 , Test Accuracy:= 0.7206000089645386
# Time : 2.70s
# Epoch = 20 , Training Cross Entropy:= 4.378356770833333 , Training Accuracy:= 0.7284666895866394 , Test Accuracy:= 0.7233999967575073
# Time : 2.71s
# Epoch = 21 , Training Cross Entropy:= 4.377119791666667 , Training Accuracy:= 0.7280333042144775 , Test Accuracy:= 0.7233999967575073
# Time : 2.71s
# Epoch = 22 , Training Cross Entropy:= 4.3801713541666665 , Training Accuracy:= 0.7293999791145325 , Test Accuracy:= 0.7264999747276306
# Time : 2.69s
# Epoch = 23 , Training Cross Entropy:= 4.330131770833333 , Training Accuracy:= 0.7317333221435547 , Test Accuracy:= 0.727400004863739
# Time : 2.69s
# Epoch = 24 , Training Cross Entropy:= 4.319845572916667 , Training Accuracy:= 0.7237833142280579 , Test Accuracy:= 0.7167999744415283
# Time : 2.73s
# Epoch = 25 , Training Cross Entropy:= 4.3149395833333335 , Training Accuracy:= 0.7349333167076111 , Test Accuracy:= 0.7290999889373779
# Time : 2.71s
# Epoch = 26 , Training Cross Entropy:= 4.288053125 , Training Accuracy:= 0.7327499985694885 , Test Accuracy:= 0.7282999753952026
# Time : 2.72s
# Epoch = 27 , Training Cross Entropy:= 4.293272135416666 , Training Accuracy:= 0.734416663646698 , Test Accuracy:= 0.7282000184059143
# Time : 2.70s
# Epoch = 28 , Training Cross Entropy:= 4.2799328125 , Training Accuracy:= 0.7344666719436646 , Test Accuracy:= 0.7303000092506409
# Time : 2.70s
# Epoch = 29 , Training Cross Entropy:= 4.252355729166666 , Training Accuracy:= 0.7371666431427002 , Test Accuracy:= 0.7304999828338623
# Time : 2.69s
# Epoch = 30 , Training Cross Entropy:= 4.2613208333333334 , Training Accuracy:= 0.735450029373169 , Test Accuracy:= 0.7307999730110168
# Time : 2.73s
# Epoch = 31 , Training Cross Entropy:= 4.2432296875 , Training Accuracy:= 0.7368333339691162 , Test Accuracy:= 0.734000027179718
# Time : 2.74s
# Epoch = 32 , Training Cross Entropy:= 4.2495596354166665 , Training Accuracy:= 0.7319333553314209 , Test Accuracy:= 0.7272999882698059
# Time : 2.70s
# Epoch = 33 , Training Cross Entropy:= 4.229615625 , Training Accuracy:= 0.739133358001709 , Test Accuracy:= 0.7336000204086304
# Time : 2.70s
# Epoch = 34 , Training Cross Entropy:= 4.22011328125 , Training Accuracy:= 0.7380499839782715 , Test Accuracy:= 0.7337999939918518
# Time : 2.70s
# Epoch = 35 , Training Cross Entropy:= 4.178948697916667 , Training Accuracy:= 0.7371666431427002 , Test Accuracy:= 0.7304999828338623
# Time : 2.70s
# Epoch = 36 , Training Cross Entropy:= 4.185298958333333 , Training Accuracy:= 0.7437833547592163 , Test Accuracy:= 0.7368999719619751
# Time : 2.71s
# Epoch = 37 , Training Cross Entropy:= 4.17910625 , Training Accuracy:= 0.7422666549682617 , Test Accuracy:= 0.7366999983787537
# Time : 2.72s
# Epoch = 38 , Training Cross Entropy:= 4.1650703125 , Training Accuracy:= 0.7380499839782715 , Test Accuracy:= 0.7311000227928162
# Time : 2.69s
# Epoch = 39 , Training Cross Entropy:= 4.157534635416667 , Training Accuracy:= 0.7423999905586243 , Test Accuracy:= 0.7368999719619751
# Time : 2.73s
# Epoch = 40 , Training Cross Entropy:= 4.158047395833333 , Training Accuracy:= 0.7432000041007996 , Test Accuracy:= 0.7365000247955322
# Time : 2.69s
# Epoch = 41 , Training Cross Entropy:= 4.1502755208333335 , Training Accuracy:= 0.743399977684021 , Test Accuracy:= 0.7383999824523926
# Time : 2.71s
# Epoch = 42 , Training Cross Entropy:= 4.125791666666666 , Training Accuracy:= 0.7447500228881836 , Test Accuracy:= 0.7379000186920166
# Time : 2.70s
# Epoch = 43 , Training Cross Entropy:= 4.1195796875 , Training Accuracy:= 0.7450666427612305 , Test Accuracy:= 0.7401000261306763
# Time : 2.72s
# Epoch = 44 , Training Cross Entropy:= 4.1057854166666665 , Training Accuracy:= 0.7474166750907898 , Test Accuracy:= 0.7421000003814697
# Time : 2.72s
# Epoch = 45 , Training Cross Entropy:= 4.090615885416667 , Training Accuracy:= 0.7469666600227356 , Test Accuracy:= 0.7415000200271606
# Time : 2.68s
# Epoch = 46 , Training Cross Entropy:= 4.089268229166667 , Training Accuracy:= 0.7491499781608582 , Test Accuracy:= 0.7425000071525574
# Time : 2.64s
# Epoch = 47 , Training Cross Entropy:= 4.077530208333333 , Training Accuracy:= 0.7484166622161865 , Test Accuracy:= 0.7421000003814697
# Time : 2.66s
# Epoch = 48 , Training Cross Entropy:= 4.0870645833333334 , Training Accuracy:= 0.7497833371162415 , Test Accuracy:= 0.7433000206947327
# Time : 2.73s
# Epoch = 49 , Training Cross Entropy:= 4.076698697916667 , Training Accuracy:= 0.7483166456222534 , Test Accuracy:= 0.7407000064849854
# Time : 2.74s
# Epoch = 50 , Training Cross Entropy:= 4.071772395833333 , Training Accuracy:= 0.7505000233650208 , Test Accuracy:= 0.7432000041007996
# Time : 2.74s
# Epoch = 1 , Training Cross Entropy:= 9.78335625 , Training Accuracy:= 0.5091666579246521 , Test Accuracy:= 0.510200023651123
# Time : 2.74s
# Epoch = 2 , Training Cross Entropy:= 7.3026723958333335 , Training Accuracy:= 0.5985166430473328 , Test Accuracy:= 0.6075000166893005
# Time : 2.72s
# Epoch = 3 , Training Cross Entropy:= 6.217801041666666 , Training Accuracy:= 0.6251333355903625 , Test Accuracy:= 0.6313999891281128
# Time : 2.68s
# Epoch = 4 , Training Cross Entropy:= 5.9668234375 , Training Accuracy:= 0.6339499950408936 , Test Accuracy:= 0.6376000046730042
# Time : 2.70s
# Epoch = 5 , Training Cross Entropy:= 5.833278125 , Training Accuracy:= 0.6459000110626221 , Test Accuracy:= 0.6478000283241272
# Time : 2.75s
# Epoch = 6 , Training Cross Entropy:= 5.718238020833334 , Training Accuracy:= 0.6522833108901978 , Test Accuracy:= 0.6523000001907349
# Time : 2.70s
# Epoch = 7 , Training Cross Entropy:= 5.620021875 , Training Accuracy:= 0.6496999859809875 , Test Accuracy:= 0.6506999731063843
# Time : 2.71s
# Epoch = 8 , Training Cross Entropy:= 5.5974916666666665 , Training Accuracy:= 0.6575833559036255 , Test Accuracy:= 0.6593000292778015
# Time : 2.70s
# Epoch = 9 , Training Cross Entropy:= 5.541296875 , Training Accuracy:= 0.6567666530609131 , Test Accuracy:= 0.6611999869346619
# Time : 2.71s
# Epoch = 10 , Training Cross Entropy:= 5.494461979166666 , Training Accuracy:= 0.6571000218391418 , Test Accuracy:= 0.6588000059127808
# Time : 2.69s
# Epoch = 11 , Training Cross Entropy:= 5.47330625 , Training Accuracy:= 0.6626333594322205 , Test Accuracy:= 0.6625999808311462
# Time : 2.69s
# Epoch = 12 , Training Cross Entropy:= 5.3604546875 , Training Accuracy:= 0.6758833527565002 , Test Accuracy:= 0.6761999726295471
# Time : 2.68s
# Epoch = 13 , Training Cross Entropy:= 5.2102354166666665 , Training Accuracy:= 0.6858833432197571 , Test Accuracy:= 0.6870999932289124
# Time : 2.69s
# Epoch = 14 , Training Cross Entropy:= 5.043916666666667 , Training Accuracy:= 0.6914166808128357 , Test Accuracy:= 0.6916000247001648
# Time : 2.73s
# Epoch = 15 , Training Cross Entropy:= 4.885744270833333 , Training Accuracy:= 0.699566662311554 , Test Accuracy:= 0.6959999799728394
# Time : 2.72s
# Epoch = 16 , Training Cross Entropy:= 4.6671421875 , Training Accuracy:= 0.720966637134552 , Test Accuracy:= 0.7190999984741211
# Time : 2.69s
# Epoch = 17 , Training Cross Entropy:= 4.510700520833334 , Training Accuracy:= 0.7301166653633118 , Test Accuracy:= 0.7297999858856201
# Time : 2.86s
# Epoch = 18 , Training Cross Entropy:= 4.386804166666667 , Training Accuracy:= 0.7348999977111816 , Test Accuracy:= 0.7324000000953674
# Time : 2.71s
# Epoch = 19 , Training Cross Entropy:= 4.35744453125 , Training Accuracy:= 0.734666645526886 , Test Accuracy:= 0.734499990940094
# Time : 2.71s
# Epoch = 20 , Training Cross Entropy:= 4.279404427083334 , Training Accuracy:= 0.73089998960495 , Test Accuracy:= 0.7321000099182129
# Time : 2.71s
# Epoch = 21 , Training Cross Entropy:= 4.243457291666667 , Training Accuracy:= 0.7391666769981384 , Test Accuracy:= 0.7376000285148621
# Time : 2.70s
# Epoch = 22 , Training Cross Entropy:= 4.229623697916667 , Training Accuracy:= 0.7408000230789185 , Test Accuracy:= 0.7404999732971191
# Time : 2.70s
# Epoch = 23 , Training Cross Entropy:= 4.147857291666667 , Training Accuracy:= 0.7422333359718323 , Test Accuracy:= 0.7394000291824341
# Time : 2.69s
# Epoch = 24 , Training Cross Entropy:= 4.1276627604166665 , Training Accuracy:= 0.7386000156402588 , Test Accuracy:= 0.7343000173568726
# Time : 2.82s
# Epoch = 25 , Training Cross Entropy:= 4.117757552083333 , Training Accuracy:= 0.7385500073432922 , Test Accuracy:= 0.7369999885559082
# Time : 2.71s
# Epoch = 26 , Training Cross Entropy:= 4.123772395833333 , Training Accuracy:= 0.7486666440963745 , Test Accuracy:= 0.7473999857902527
# Time : 2.69s
# Epoch = 27 , Training Cross Entropy:= 4.0671328125 , Training Accuracy:= 0.748283326625824 , Test Accuracy:= 0.7470999956130981
# Time : 2.69s
# Epoch = 28 , Training Cross Entropy:= 4.070520052083333 , Training Accuracy:= 0.7462166547775269 , Test Accuracy:= 0.7444999814033508
# Time : 2.80s
# Epoch = 29 , Training Cross Entropy:= 4.069086979166666 , Training Accuracy:= 0.7484999895095825 , Test Accuracy:= 0.746399998664856
# Time : 3.03s
# Epoch = 49 , Training Cross Entropy:= 3.8587994791666667 , Training Accuracy:= 0.7560499906539917 , Test Accuracy:= 0.7527999877929688
# Time : 2.69s
# Epoch = 50 , Training Cross Entropy:= 3.859870052083333 , Training Accuracy:= 0.7580500245094299 , Test Accuracy:= 0.7559000253677368
# Time : 2.67s
# Epoch = 1 , Training Cross Entropy:= 11.374148958333333 , Training Accuracy:= 0.3766833245754242 , Test Accuracy:= 0.3783999979496002
# Time : 2.73s
# Epoch = 2 , Training Cross Entropy:= 9.454955208333333 , Training Accuracy:= 0.4492500126361847 , Test Accuracy:= 0.4519999921321869
# Time : 2.72s
# Epoch = 3 , Training Cross Entropy:= 8.561354166666666 , Training Accuracy:= 0.4900333285331726 , Test Accuracy:= 0.4975999891757965
# Time : 2.68s
# Epoch = 4 , Training Cross Entropy:= 7.980484895833333 , Training Accuracy:= 0.5325166583061218 , Test Accuracy:= 0.5410000085830688
# Time : 2.76s
# Epoch = 5 , Training Cross Entropy:= 7.376452083333334 , Training Accuracy:= 0.5503166913986206 , Test Accuracy:= 0.5565000176429749
# Time : 2.74s
# Epoch = 6 , Training Cross Entropy:= 7.171916666666666 , Training Accuracy:= 0.5463833212852478 , Test Accuracy:= 0.5516999959945679
# Time : 2.70s
# Epoch = 7 , Training Cross Entropy:= 7.094511979166667 , Training Accuracy:= 0.5600333213806152 , Test Accuracy:= 0.5630999803543091
# Time : 2.71s
# Epoch = 8 , Training Cross Entropy:= 7.048318229166667 , Training Accuracy:= 0.5633166432380676 , Test Accuracy:= 0.567300021648407
# Time : 2.79s
# Epoch = 9 , Training Cross Entropy:= 6.996645833333333 , Training Accuracy:= 0.5664666891098022 , Test Accuracy:= 0.569100022315979
# Time : 2.86s
# Epoch = 10 , Training Cross Entropy:= 7.0037703125 , Training Accuracy:= 0.5710833072662354 , Test Accuracy:= 0.5745000243186951
# Time : 2.72s
# Epoch = 11 , Training Cross Entropy:= 6.925056770833334 , Training Accuracy:= 0.5684166550636292 , Test Accuracy:= 0.5712000131607056
# Time : 2.73s
# Epoch = 12 , Training Cross Entropy:= 6.909750520833334 , Training Accuracy:= 0.5666166543960571 , Test Accuracy:= 0.5716000199317932
# Time : 2.70s
# Epoch = 13 , Training Cross Entropy:= 6.888596875 , Training Accuracy:= 0.5738833546638489 , Test Accuracy:= 0.5759000182151794
# Time : 2.70s
# Epoch = 14 , Training Cross Entropy:= 6.533096875 , Training Accuracy:= 0.6489499807357788 , Test Accuracy:= 0.647599995136261
# Time : 2.71s
# Epoch = 15 , Training Cross Entropy:= 5.531430208333333 , Training Accuracy:= 0.6620500087738037 , Test Accuracy:= 0.6620000004768372
# Time : 2.68s
# Epoch = 16 , Training Cross Entropy:= 5.435010416666667 , Training Accuracy:= 0.6644833087921143 , Test Accuracy:= 0.6643999814987183
# Time : 2.68s
# Epoch = 17 , Training Cross Entropy:= 5.381313020833334 , Training Accuracy:= 0.6680999994277954 , Test Accuracy:= 0.6674000024795532
# Time : 2.68s
# Epoch = 18 , Training Cross Entropy:= 5.3563734375 , Training Accuracy:= 0.6674833297729492 , Test Accuracy:= 0.6678000092506409
# Time : 2.67s
# Epoch = 19 , Training Cross Entropy:= 5.328217708333334 , Training Accuracy:= 0.6693000197410583 , Test Accuracy:= 0.6689000129699707
# Time : 2.68s
# Epoch = 20 , Training Cross Entropy:= 5.349021354166666 , Training Accuracy:= 0.6657000184059143 , Test Accuracy:= 0.666700005531311
# Time : 2.68s
# Epoch = 21 , Training Cross Entropy:= 5.336940625 , Training Accuracy:= 0.6703000068664551 , Test Accuracy:= 0.6708999872207642
# Time : 2.68s
# Epoch = 22 , Training Cross Entropy:= 5.2939859375 , Training Accuracy:= 0.6712666749954224 , Test Accuracy:= 0.6705999970436096
# Time : 2.68s
# Epoch = 23 , Training Cross Entropy:= 5.2924984375 , Training Accuracy:= 0.6725166440010071 , Test Accuracy:= 0.6736000180244446
# Time : 2.68s
# Epoch = 24 , Training Cross Entropy:= 5.271101041666666 , Training Accuracy:= 0.6742833256721497 , Test Accuracy:= 0.6746000051498413
# Time : 2.68s
# Epoch = 25 , Training Cross Entropy:= 5.26141875 , Training Accuracy:= 0.672166645526886 , Test Accuracy:= 0.671500027179718
# Time : 2.73s
# Epoch = 26 , Training Cross Entropy:= 5.278797916666667 , Training Accuracy:= 0.6717333197593689 , Test Accuracy:= 0.6741999983787537
# Time : 2.68s
# Epoch = 27 , Training Cross Entropy:= 5.233433854166667 , Training Accuracy:= 0.6744999885559082 , Test Accuracy:= 0.6747999787330627
# Time : 2.70s
# Epoch = 28 , Training Cross Entropy:= 5.238378125 , Training Accuracy:= 0.67330002784729 , Test Accuracy:= 0.6721000075340271
# Time : 2.75s
# Epoch = 29 , Training Cross Entropy:= 5.214621875 , Training Accuracy:= 0.6731500029563904 , Test Accuracy:= 0.6728000044822693
# Time : 2.77s
# Epoch = 30 , Training Cross Entropy:= 5.217663541666667 , Training Accuracy:= 0.6755666732788086 , Test Accuracy:= 0.6735000014305115
# Time : 2.69s
# Epoch = 31 , Training Cross Entropy:= 5.210591145833333 , Training Accuracy:= 0.6773499846458435 , Test Accuracy:= 0.6776999831199646
# Time : 2.69s
# Epoch = 32 , Training Cross Entropy:= 5.2043484375 , Training Accuracy:= 0.673966646194458 , Test Accuracy:= 0.6729999780654907
# Time : 2.70s
# Epoch = 33 , Training Cross Entropy:= 5.1976203125 , Training Accuracy:= 0.6779833436012268 , Test Accuracy:= 0.6787999868392944
# Time : 2.72s
# Epoch = 34 , Training Cross Entropy:= 5.186450520833334 , Training Accuracy:= 0.6791333556175232 , Test Accuracy:= 0.6794999837875366
# Time : 2.68s
# Epoch = 35 , Training Cross Entropy:= 5.2097505208333335 , Training Accuracy:= 0.6788333058357239 , Test Accuracy:= 0.6779999732971191
# Time : 2.71s
# Epoch = 36 , Training Cross Entropy:= 5.194526041666666 , Training Accuracy:= 0.6769833564758301 , Test Accuracy:= 0.6761999726295471
# Time : 2.70s
# Epoch = 37 , Training Cross Entropy:= 5.1728848958333336 , Training Accuracy:= 0.680400013923645 , Test Accuracy:= 0.6793000102043152
# Time : 2.70s
# Epoch = 38 , Training Cross Entropy:= 5.181608333333333 , Training Accuracy:= 0.6796833276748657 , Test Accuracy:= 0.6787999868392944
# Time : 2.71s
# Epoch = 39 , Training Cross Entropy:= 5.1676802083333335 , Training Accuracy:= 0.6797333359718323 , Test Accuracy:= 0.679099977016449
# Time : 2.71s
# Epoch = 40 , Training Cross Entropy:= 5.171309375 , Training Accuracy:= 0.6804666519165039 , Test Accuracy:= 0.6796000003814697
# Time : 2.72s
# Epoch = 41 , Training Cross Entropy:= 5.15660625 , Training Accuracy:= 0.6801833510398865 , Test Accuracy:= 0.6801000237464905
# Time : 2.69s
# Epoch = 42 , Training Cross Entropy:= 5.157482291666667 , Training Accuracy:= 0.6809499859809875 , Test Accuracy:= 0.6807000041007996
# Time : 2.72s
# Epoch = 43 , Training Cross Entropy:= 5.164902083333334 , Training Accuracy:= 0.6788333058357239 , Test Accuracy:= 0.6798999905586243
# Time : 2.70s
# Epoch = 44 , Training Cross Entropy:= 5.165096875 , Training Accuracy:= 0.6788166761398315 , Test Accuracy:= 0.6764000058174133
# Time : 2.75s
# Epoch = 45 , Training Cross Entropy:= 5.14701875 , Training Accuracy:= 0.6809333562850952 , Test Accuracy:= 0.6787999868392944
# Time : 2.71s
# Epoch = 46 , Training Cross Entropy:= 5.148780208333333 , Training Accuracy:= 0.6815500259399414 , Test Accuracy:= 0.6797000169754028
# Time : 2.71s
# Epoch = 47 , Training Cross Entropy:= 5.1362390625 , Training Accuracy:= 0.6823833584785461 , Test Accuracy:= 0.6812000274658203
# Time : 2.70s
# Epoch = 48 , Training Cross Entropy:= 5.133457291666667 , Training Accuracy:= 0.6802499890327454 , Test Accuracy:= 0.6804999709129333
# Time : 2.72s
# Epoch = 49 , Training Cross Entropy:= 5.139882291666667 , Training Accuracy:= 0.6826500296592712 , Test Accuracy:= 0.6816999912261963
# Time : 2.70s
# Epoch = 50 , Training Cross Entropy:= 5.127490104166666 , Training Accuracy:= 0.6823333501815796 , Test Accuracy:= 0.6808000206947327
# Time : 2.70s
# Epoch = 1 , Training Cross Entropy:= 12.395439583333333 , Training Accuracy:= 0.3723333477973938 , Test Accuracy:= 0.3684000074863434
# Time : 2.67s
# Epoch = 2 , Training Cross Entropy:= 9.500958333333333 , Training Accuracy:= 0.438400000333786 , Test Accuracy:= 0.43810001015663147
# Time : 2.72s
# Epoch = 3 , Training Cross Entropy:= 8.682933333333333 , Training Accuracy:= 0.4841666519641876 , Test Accuracy:= 0.4851999878883362
# Time : 2.69s
# Epoch = 4 , Training Cross Entropy:= 8.0215 , Training Accuracy:= 0.5199999809265137 , Test Accuracy:= 0.5223000049591064
# Time : 2.70s
# Epoch = 5 , Training Cross Entropy:= 7.638320833333333 , Training Accuracy:= 0.5321833491325378 , Test Accuracy:= 0.5299999713897705
# Time : 2.71s
# Epoch = 6 , Training Cross Entropy:= 7.505898958333334 , Training Accuracy:= 0.5396000146865845 , Test Accuracy:= 0.5390999913215637
# Time : 2.68s
# Epoch = 7 , Training Cross Entropy:= 7.450852604166666 , Training Accuracy:= 0.5405499935150146 , Test Accuracy:= 0.5394999980926514
# Time : 2.69s
# Epoch = 8 , Training Cross Entropy:= 7.377023958333333 , Training Accuracy:= 0.543066680431366 , Test Accuracy:= 0.5403000116348267
# Time : 2.70s
# Epoch = 9 , Training Cross Entropy:= 7.3220375 , Training Accuracy:= 0.548383355140686 , Test Accuracy:= 0.5455999970436096
# Time : 2.69s
# Epoch = 10 , Training Cross Entropy:= 7.30890625 , Training Accuracy:= 0.5496000051498413 , Test Accuracy:= 0.5483999848365784
# Time : 2.69s
# Epoch = 11 , Training Cross Entropy:= 7.266958333333333 , Training Accuracy:= 0.5493000149726868 , Test Accuracy:= 0.5491999983787537
# Time : 2.65s
# Epoch = 12 , Training Cross Entropy:= 7.2056015625 , Training Accuracy:= 0.5543333292007446 , Test Accuracy:= 0.5515000224113464
# Time : 2.68s
# Epoch = 13 , Training Cross Entropy:= 7.1796875 , Training Accuracy:= 0.5533999800682068 , Test Accuracy:= 0.5497999787330627
# Time : 2.71s
# Epoch = 14 , Training Cross Entropy:= 7.185904166666667 , Training Accuracy:= 0.5445666909217834 , Test Accuracy:= 0.5424000024795532
# Time : 2.70s
# Epoch = 15 , Training Cross Entropy:= 7.161530208333334 , Training Accuracy:= 0.5577499866485596 , Test Accuracy:= 0.5557000041007996
# Time : 2.69s
# Epoch = 16 , Training Cross Entropy:= 7.159649479166666 , Training Accuracy:= 0.5593666434288025 , Test Accuracy:= 0.5568000078201294
# Time : 2.68s
# Epoch = 17 , Training Cross Entropy:= 7.1238166666666665 , Training Accuracy:= 0.558983325958252 , Test Accuracy:= 0.555400013923645
# Time : 2.69s
# Epoch = 18 , Training Cross Entropy:= 7.110458333333334 , Training Accuracy:= 0.557783305644989 , Test Accuracy:= 0.5527999997138977
# Time : 2.69s
# Epoch = 19 , Training Cross Entropy:= 7.13523125 , Training Accuracy:= 0.553766667842865 , Test Accuracy:= 0.5496000051498413
# Time : 2.73s
# Epoch = 20 , Training Cross Entropy:= 7.093869791666667 , Training Accuracy:= 0.5574833154678345 , Test Accuracy:= 0.5533000230789185
# Time : 2.70s
# Epoch = 21 , Training Cross Entropy:= 7.083955208333333 , Training Accuracy:= 0.5537166595458984 , Test Accuracy:= 0.5498999953269958
# Time : 2.74s
# Epoch = 22 , Training Cross Entropy:= 7.078950520833334 , Training Accuracy:= 0.5615166425704956 , Test Accuracy:= 0.5562999844551086
# Time : 2.68s
# Epoch = 23 , Training Cross Entropy:= 7.080940104166666 , Training Accuracy:= 0.5633333325386047 , Test Accuracy:= 0.5591999888420105
# Time : 2.69s

# %%
loss_res.var()
# Out:
# 0.8441758087876516

# %%
loss_res.mean()
# Out:
# 4.772867447916667

# %%
train_acc.mean()
# Out:
# 0.7036133289337159

# %%
train_acc.var()
# Out:
# 0.0031539036356461733

# %%
test_acc.mean()
# Out:
# 0.7009700000286102

# %%
test_acc.var()
# Out:
# 0.003102608525094617
